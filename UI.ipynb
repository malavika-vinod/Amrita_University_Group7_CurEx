# %%
import dash
from dash import dcc
from dash import html

# %%
import pandas as pd
import numpy as np
import plotly.graph_objs as go
from datetime import datetime as dt

df=pd.read_csv('Exchange_Rate_Report_2013.csv')
s1='Highest rate :87, date: 9-11-2022'
x=[18,16,28]
y=[4,6,8]
l=[]
flag=0
for i in df.columns:
    if flag==0:
        flag=1
        continue
    l.append(i)

# %%
app=dash.Dash()

# %%
app.layout=html.Div([
    html.Div(children=[
            dcc.Dropdown(
        id='first-dropdown',
        options = {'label': 'U.S.dollar(USD)'},
        value='USD',
        style={
                'width':'20vw',
                'height':'5vh',
                'padding':'0px',
                'margin':'0px',
                'margin-bottom':'20px'
            }
    ),
            dcc.Dropdown(
        id='second-dropdown',
        options = l,
        value='NYC',
        style={
                'width':'20vw',
                'height':'5vh',
                'padding':'0px',
                'margin':'0px',
                'margin-bottom':'20px'
            }
    ),
        html.H3(s1,
            style={
                'color': '#ffffff'
            }
           ),
        html.H3(s1,
            style={
                'color': '#ffffff'
            }
           )
        ],
            style={
                'background-color': '#36454F',#left
                'width':'40vw',
                'padding':'0px',
                'margin':'20px',
                'display':'flex',
                'flex-direction': 'column',
                'justify-content': 'center',
                'align-items': 'center'
            }
            ),
    html.Div(children=[
         html.Div(children=[
              html.Button("7D"),
              html.Button("1M"),
              html.Button("3M"),
              html.Button("1Y"),
              html.Button("Custom")
         ],
            style={
                'background-color': '#FFFF00',
                'width':'30vw',
                'padding':'0px',
                'margin':'0px',
                'display':'flex',
                'justify-content': 'space-between',
                'align-items': 'center'
                
            }
            ),
        
            dcc.DatePickerRange(
        id = 'dt-pick-range',
        start_date=dt(2015,5,10),
        end_date=dt(2018,7,11)
    ),
        html.Button("Show"),
        
        dcc.Graph(
        id = 'sample-graph',
        figure = {
            'data' : [
                {'x' : x,'y':y,'type':'line', 'name':'chart1' },
            ],
            'layout' : {
                'plot_bgcolor' : '#D3D3D3',
                'paper_bgcolor' : '#00FFFF',
                'font' : {
                    'color' : '#ff0000'
                },
                'title' : 'Simple bar Chart'
            }
        }
        
    ),
        
    ]
             
             ,
            style={
                'background-color': '#36454F',#gright
                'width':'60vw',
                'padding':'0px',
                'margin':'20px',
                'display':'flex',
                'flex-direction': 'column',
                'justify-content': 'center',
                'align-items': 'center'
            }
            )
    ],
            style={
                'position':'fixed',
                'background-color': '#191970',#blue
                'height':'100vh',
                'width':'100vw',
                'display':'flex',
                'padding':'0px',
                'margin':'0px',
                
            }
            )

# %%
if __name__=='__main__':
    app.run_server(port =4055)
# Out:
# Dash is running on http://127.0.0.1:4055/
#
#  * Serving Flask app "__main__" (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: off
#  * Running on http://127.0.0.1:4055/ (Press CTRL+C to quit)
# 127.0.0.1 - - [09/Nov/2022 09:20:37] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Nov/2022 09:20:37] "GET /_dash-dependencies HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Nov/2022 09:20:37] "GET /_dash-layout HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Nov/2022 09:20:37] "GET /_favicon.ico?v=2.7.0 HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Nov/2022 09:20:37] "GET /_dash-component-suites/dash/dcc/async-dropdown.js HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Nov/2022 09:20:37] "GET /_dash-component-suites/dash/dcc/async-datepicker.js HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Nov/2022 09:20:37] "GET /_dash-component-suites/dash/dcc/async-graph.js HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Nov/2022 09:20:37] "GET /_dash-component-suites/dash/dcc/async-plotlyjs.js HTTP/1.1" 200 -
